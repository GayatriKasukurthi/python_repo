# %%
import pandas as pd
data = {
    "empid": [101,102, 103],
    "empname": ["gayatri", "gay", "ammul"],
    "salary":[64330, 74125, 100000]
    }
df = pd.DataFrame(data) # syntax to create a dataframe
print(df)
# Out:
#    empid  empname  salary
# 0    101  gayatri   64330
# 1    102      gay   74125
# 2    103    ammul  100000

# %%
df = pd.read_csv(r"C:\Users\ammul\Downloads\python_practice_files\sales_data.csv") # syntax to read a csv file
print(df)
# Out:
#     OrderID   OrderDate Region   Product  Quantity  UnitPrice  TotalAmount
# 0      1001  2026-01-05  South    Laptop         2      55000       110000
# 1      1002  2026-01-07  North     Mouse        10        800         8000
# 2      1003  2026-01-10   East  Keyboard         5       1800         9000
# 3      1004  2026-01-15   West   Monitor         3      12000        36000
# 4      1005  2026-02-02  South    Laptop         1      55000        55000
# 5      1006  2026-02-08  North   Headset         4       2500        10000
# 6      1007  2026-02-14   East     Mouse         8        800         6400
# 7      1008  2026-02-20   West   Monitor         2      12000        24000
# 8      1009  2026-03-01  South  Keyboard         6       1800        10800
# 9      1010  2026-03-05  North    Laptop         2      55000       110000
# 10     1011  2026-03-12   East   Headset         3       2500         7500
# ...

# %%
# Imagine you have 10 million rows and 50 columns, but you only need the Sales column.

# With Parquet, the system can efficiently read just the needed column instead of processing the whole table. That's one reason Parquet is commonly used in data engineering, Databricks, Spark, and analytics.

# CSV → easy to read/share
# Parquet → efficient for large-scale data processing

# %%
print(df.head())
print(df.tail())
# Out:
#    OrderID   OrderDate Region   Product  Quantity  UnitPrice  TotalAmount
# 0     1001  2026-01-05  South    Laptop         2      55000       110000
# 1     1002  2026-01-07  North     Mouse        10        800         8000
# 2     1003  2026-01-10   East  Keyboard         5       1800         9000
# 3     1004  2026-01-15   West   Monitor         3      12000        36000
# 4     1005  2026-02-02  South    Laptop         1      55000        55000
#     OrderID   OrderDate Region   Product  Quantity  UnitPrice  TotalAmount
# 7      1008  2026-02-20   West   Monitor         2      12000        24000
# 8      1009  2026-03-01  South  Keyboard         6       1800        10800
# 9      1010  2026-03-05  North    Laptop         2      55000       110000
# 10     1011  2026-03-12   East   Headset         3       2500         7500
# 11     1012  2026-03-18   West     Mouse        12        800         9600

# %%
print(df.columns)
# Out:
# Index(['OrderID', 'OrderDate', 'Region', 'Product', 'Quantity', 'UnitPrice',
#        'TotalAmount'],
#       dtype='str')

# %%
print(df.dtypes)
# Out:
# OrderID        int64
# OrderDate        str
# Region           str
# Product          str
# Quantity       int64
# UnitPrice      int64
# TotalAmount    int64
# dtype: object

# %%
print(df[["OrderID", "OrderDate"]])
# Out:
#     OrderID   OrderDate
# 0      1001  2026-01-05
# 1      1002  2026-01-07
# 2      1003  2026-01-10
# 3      1004  2026-01-15
# 4      1005  2026-02-02
# 5      1006  2026-02-08
# 6      1007  2026-02-14
# 7      1008  2026-02-20
# 8      1009  2026-03-01
# 9      1010  2026-03-05
# 10     1011  2026-03-12
# 11     1012  2026-03-18

# %%
print(df)
# Out:
#     OrderID   OrderDate Region   Product  Quantity  UnitPrice  TotalAmount
# 0      1001  2026-01-05  South    Laptop         2      55000       110000
# 1      1002  2026-01-07  North     Mouse        10        800         8000
# 2      1003  2026-01-10   East  Keyboard         5       1800         9000
# 3      1004  2026-01-15   West   Monitor         3      12000        36000
# 4      1005  2026-02-02  South    Laptop         1      55000        55000
# 5      1006  2026-02-08  North   Headset         4       2500        10000
# 6      1007  2026-02-14   East     Mouse         8        800         6400
# 7      1008  2026-02-20   West   Monitor         2      12000        24000
# 8      1009  2026-03-01  South  Keyboard         6       1800        10800
# 9      1010  2026-03-05  North    Laptop         2      55000       110000
# 10     1011  2026-03-12   East   Headset         3       2500         7500
# ...

# %%
df.fillna(0, inplace=True)
# Out:
#     OrderID   OrderDate Region   Product  Quantity  UnitPrice  TotalAmount
# 0      1001  2026-01-05  South    Laptop         2      55000       110000
# 1      1002  2026-01-07  North     Mouse        10        800         8000
# 2      1003  2026-01-10   East  Keyboard         5       1800         9000
# 3      1004  2026-01-15   West   Monitor         3      12000        36000
# 4      1005  2026-02-02  South    Laptop         1      55000        55000
# 5      1006  2026-02-08  North   Headset         4       2500        10000
# 6      1007  2026-02-14   East     Mouse         8        800         6400
# 7      1008  2026-02-20   West   Monitor         2      12000        24000
# 8      1009  2026-03-01  South  Keyboard         6       1800        10800
# 9      1010  2026-03-05  North    Laptop         2      55000       110000
# 10     1011  2026-03-12   East   Headset         3       2500         7500
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.sort_values(by="TotalAmount", ascending=True, inplace=True)
print(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.sort_values(by="TotalAmount", ascending=True, inplace=True)
#       2 print(df)
#
# NameError: name 'df' is not defined
